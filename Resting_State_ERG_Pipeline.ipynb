# %% [markdown]
# # 1. Load multichannel filtered fif file and calculate power spectral density

# %%
import psd_compute

# %% [markdown]
# # 2. Artifact removal in power spectral density

# %%
import psd_clean_v1b

# %% [markdown]
# # 3. Power spectral density averaging

# %%
import psd_channel_means_v1b

# %% [markdown]
# # 4. Aperiodic fitting using FOOOF

# %%
import excel_to_1darray_to_FOOOF_v1A11_agg

# %% [markdown]
# # 5. Cycle by cycle burst detection on multichannel filtered fif file

# %%
import MEA_burst_detect_v9C8
MEA_burst_detect_v9C8.main()

# %% [markdown]
# # 6. Multimetric burst analysis on averaged multichannel

# %%
from Cycle_Hilb_Spect_pACF_v9C2Nv2E_env50_piecewise_consistency_autoGUI_artToggle_promPctGuardFinal import RSEGViewer

viewer = RSEGViewer()

# Turn artifact rejection OFF either in the UI or programmatically:
viewer.set_artifact_rejection(False)
# Out:
# /Users/davidlitvin/anaconda3/lib/python3.11/site-packages/jupyter_client/session.py:721: UserWarning: Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#   content = self.pack(content)
# ...
